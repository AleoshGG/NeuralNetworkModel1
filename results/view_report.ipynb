# %%
import pandas as pd

df = pd.read_csv('reporte_red_neuronal.csv')
df
# Out:
#       Lambda  Epocas                                          W_inicial  \
# 0   0.000001    1000  [0.4967, -0.1383, 0.6477, 1.523, -0.2342, -0.2...
# 1   1.000000     150  [0.4967, -0.1383, 0.6477, 1.523, -0.2342, -0.2...
# 2  10.000000      50  [0.4967, -0.1383, 0.6477, 1.523, -0.2342, -0.2...
# 3   0.890000     800  [0.4967, -0.1383, 0.6477, 1.523, -0.2342, -0.2...
# 4   3.141600     360  [0.4967, -0.1383, 0.6477, 1.523, -0.2342, -0.2...
#
#                                              W_final  |Error_Final|
# 0  [0.4964, 0.1195, -0.1294, -0.0914, 0.0946, 0.141]            0.0
# 1  [20.4967, 32199.7017, -34664.4623, -24372.967,...            0.0
# 2  [200.4967, 321998.2617, -346650.4523, -243743....            0.0
# 3  [18.2967, 28657.7193, -30851.3002, -21691.7731...            0.0
# 4  [63.3287, 101158.8791, -108903.2619, -76573.37...            0.0
